# %% [markdown]
# <a href="https://colab.research.google.com/github/JonDesu/JupyterNotebooks/blob/master/sportsreference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install sportsreference
# Out:
# ...
#     100% |████████████████████████████████| 368kB 14.6MB/s
# ...
